# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %% [markdown]
# #adding coloumn
#     -list cmprehension
#     -lamda func
#     -python func

# %%
data["Gender"] = ["m","f","m","f","m","f","m","f","m","f","m","f","m","f","m","f","m","f","m","f","m","f","m","f","m","f","m","f","m","f","m","f",]

# %%
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories Gender
# 0         60  '2020/12/01'    110       130     409.1      m
# 1         60  '2020/12/02'    117       145     479.0      f
# 2         60  '2020/12/03'    103       135     340.0      m
# 3         45  '2020/12/04'    109       175     282.4      f
# 4         45  '2020/12/05'    117       148     406.0      m
# 5         60  '2020/12/06'    102       127     300.0      f
# 6         60  '2020/12/07'    110       136     374.0      m
# 7        450  '2020/12/08'    104       134     253.3      f
# 8         30  '2020/12/09'    109       133     195.1      m
# 9         60  '2020/12/10'     98       124     269.0      f
# 10        60  '2020/12/11'    103       147     329.3      m
# 11        60  '2020/12/12'    100       120     250.7      f
# 12        60  '2020/12/12'    100       120     250.7      m
# 13        60  '2020/12/13'    106       128     345.3      f
# ...

# %%
data["RealGender"] = ["Male" if Pulse>100 else "Female" for Pulse in data.Pulse  ]
data
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories Gender RealGender
# 0         60  '2020/12/01'    110       130     409.1      m       Male
# 1         60  '2020/12/02'    117       145     479.0      f       Male
# 2         60  '2020/12/03'    103       135     340.0      m       Male
# 3         45  '2020/12/04'    109       175     282.4      f       Male
# 4         45  '2020/12/05'    117       148     406.0      m       Male
# 5         60  '2020/12/06'    102       127     300.0      f       Male
# 6         60  '2020/12/07'    110       136     374.0      m       Male
# 7        450  '2020/12/08'    104       134     253.3      f       Male
# 8         30  '2020/12/09'    109       133     195.1      m       Male
# 9         60  '2020/12/10'     98       124     269.0      f     Female
# 10        60  '2020/12/11'    103       147     329.3      m       Male
# 11        60  '2020/12/12'    100       120     250.7      f     Female
# ...

# %%
emp = pd.read_csv("emp.csv")

# %%
emp.describe
# Out:
# <bound method NDFrame.describe of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
emp.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
emp.drop(['EducationField', 'EmployeeCount',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager'],axis = 1 ,inplace = True )

# %%
emp
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education
# 0                    1          2
# ...

# %%
###loc and iloc

# %%
emp.iloc[88:89,:7]
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 88   30        No  Travel_Rarely        288  Research & Development
#
#     DistanceFromHome  Education
# 88                 2          3

# %%
emp.loc[89:100,["DailyRate","Department"]]
# Out:
#      DailyRate              Department
# 89         669                   Sales
# 90         530  Research & Development
# 91         632                   Sales
# 92        1334                   Sales
# 93         638  Research & Development
# 94        1093                   Sales
# 95        1217  Research & Development
# 96        1353                   Sales
# 97         120                   Sales
# 98         682                   Sales
# 99         489  Research & Development
# 100        807         Human Resources

# %%
emp.iloc[1:100,1:5]
emp.size
emp.shape
emp.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education  Floor Gender
# 0                 1          2      1   Male
# 1                 8          1    109  other
# 2                 2          2    109  other
# 3                 3          4    109  other
# 4                 2          1    109  other

# %%
emp.rename(columns={"Attrition": "Gpa"}, inplace = True)
emp.columns
# Out:
# Index(['Age', '', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'Floor', 'Gender'],
#       dtype='object')

# %%
emp.values
emp.index
emp.columns
emp.info
emp.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education        Floor
# count  1470.000000  1470.000000       1470.000000  1470.000000  1470.000000
# mean     36.923810   802.485714          9.192517     2.912925    74.518367
# std       9.135373   403.509100          8.106864     1.024165    49.194596
# min      18.000000   102.000000          1.000000     1.000000     1.000000
# 25%      30.000000   465.000000          2.000000     2.000000     1.000000
# 50%      36.000000   802.000000          7.000000     3.000000   109.000000
# 75%      43.000000  1157.000000         14.000000     4.000000   109.000000
# max      60.000000  1499.000000         29.000000     5.000000   109.000000

# %%
emp.sample(7)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 357    21       Yes  Travel_Frequently        756                   Sales
# 1323   28        No         Non-Travel        280         Human Resources
# 1092   45        No      Travel_Rarely        950  Research & Development
# 1093   42        No  Travel_Frequently        288  Research & Development
# 1161   38        No      Travel_Rarely        397  Research & Development
# 343    29        No      Travel_Rarely        144                   Sales
# 42     26       Yes      Travel_Rarely       1357  Research & Development
#
#       DistanceFromHome  Education  Floor  Gender
# 357                  1          1      1    Male
# 1323                 1          2     69  Female
# 1092                28          3    109   other
# 1093                 2          3    109   other
# 1161                 2          2    109   other
# 343                 10          1      1    Male
# ...

# %%
emp.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education  Floor Gender
# 1465                23          2    109  other
# 1466                 6          1    109  other
# 1467                 4          3    109  other
# 1468                 2          3      1   Male
# 1469                 8          3    109  other

# %%
emp.loc[1:11, "Age":"Department"]
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# 5    32        No  Travel_Frequently       1005  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 7    30        No      Travel_Rarely       1358  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 11   29        No      Travel_Rarely        153  Research & Development

# %%
###lambda function appply

# %%
emp["Gender"] = emp.Department.apply(lambda x: "Male" if x== "Sales" else "Female" if x == "Human Resources" else "other" )

# %%
emp.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
####maping in data

# %%
emp.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
emp
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education  Floor
# ...

# %%
 emp[ "Floor"]= emp.Department.map(adic)

# %%
adic = {'Sales':1, 'Research & Development':109, 'Human Resources':69}
