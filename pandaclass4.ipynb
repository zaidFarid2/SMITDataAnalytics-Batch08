# %%
import pandas as pd
data  = pd.read_csv("series.csv")
data
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   object
#  6   Star1          1000 non-null   object
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.3+ KB

# %%
data.Released_Year.unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943', 'PG'], dtype=object)

# %%
data[data.Released_Year == "PG"]
# Out:
#     Series_Title Released_Year  Runtime      Genre  IMDB_Rating    Director  \
# 966    Apollo 13            PG      140  Adventure          7.6  Ron Howard
#
#          Star1  No_of_Votes        Gross  Metascore
# 966  Tom Hanks       269197  173837933.0       77.0

# %%
data.loc[966:966,"Released_Year"] = "2016"

# %%
data.Released_Year.unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943'], dtype=object)

# %%
data.Released_Year = data.Released_Year.astype(int)

# %%
data.Released_Year.dtype
# Out:
# dtype('int64')

# %%
data[data.Released_Year == 2008 ]["Series_Title"]
# Out:
# 2                          The Dark Knight
# 66                                  WALL·E
# 224                            A Wednesday
# 225                            Gran Torino
# 227                              Okuribito
# 351                                Yip Man
# 354                    Slumdog Millionaire
# 487                 Låt den rätte komma in
# 489                           The Wrestler
# 494                              In Bruges
# 502                               Iron Man
# 608                             Chugyeokja
# 615                                  Taken
# 616         The Boy in the Striped Pyjamas
# 628    The Curious Case of Benjamin Button
# 756                    Gake no ue no Ponyo
# 757                            Frost/Nixon
# 759                             Changeling
# 913                              Die Welle
# 917                           Seven Pounds
# 933                   Synecdoche, New York
# Name: Series_Title, dtype: object

# %%
data[(data.Released_Year == 2008) & (data.Genre == "Action") ]
# Out:
#         Series_Title  Released_Year  Runtime   Genre  IMDB_Rating  \
# 2    The Dark Knight           2008      152  Action          9.0
# 224      A Wednesday           2008      104  Action          8.1
# 351          Yip Man           2008      106  Action          8.0
# 502         Iron Man           2008      126  Action          7.9
# 608       Chugyeokja           2008      125  Action          7.8
# 615            Taken           2008       90  Action          7.8
#
#               Director              Star1  No_of_Votes        Gross  Metascore
# 2    Christopher Nolan     Christian Bale      2303232  534858444.0       84.0
# 224      Neeraj Pandey        Anupam Kher        73891  573329738.0        NaN
# 351         Wilson Yip         Donnie Yen       211427  613703997.0       59.0
# 502        Jon Favreau  Robert Downey Jr.       939644  318412101.0       79.0
# 608        Hong-jin Na      Kim Yoon-seok        58468  369366051.0       64.0
# ...

# %%
data[data.Released_Year == 2008]["Gross"].sum()
# Out:
# np.float64(4309064000.0)

# %%
data.Gross.max()
# Out:
# np.float64(936662225.0)

# %%
data[data.Gross == data.Gross.max()]
# Out:
#                                    Series_Title  Released_Year  Runtime  \
# 477  Star Wars: Episode VII - The Force Awakens           2015      138
#
#       Genre  IMDB_Rating     Director         Star1  No_of_Votes        Gross  \
# 477  Action          7.9  J.J. Abrams  Daisy Ridley       860823  936662225.0
#
#      Metascore
# 477       80.0

# %%
data[data.Runtime == data.Runtime.max()]
# Out:
#            Series_Title  Released_Year  Runtime   Genre  IMDB_Rating  \
# 140  Gangs of Wasseypur           2012      321  Action          8.2
#
#            Director           Star1  No_of_Votes      Gross  Metascore
# 140  Anurag Kashyap  Manoj Bajpayee        82365  5257741.0       89.0

# %%
data.Director.value_counts()
# Out:
# Director
# Alfred Hitchcock    14
# Steven Spielberg    13
# Hayao Miyazaki      11
# Akira Kurosawa      10
# Martin Scorsese     10
#                     ..
# Kinji Fukasaku       1
# Eric Bress           1
# Thomas Kail          1
# Irvin Kershner       1
# Lana Wachowski       1
# Name: count, Length: 548, dtype: int64

# %%
data[data.Genre == "Comedy"]["Director"].value_counts()
# Out:
# Director
# Woody Allen        8
# Charles Chaplin    5
# Billy Wilder       4
# Rajkumar Hirani    4
# Emir Kusturica     3
#                   ..
# Marc Caro          1
# Chris Columbus     1
# David Zucker       1
# Richard Lester     1
# Blake Edwards      1
# Name: count, Length: 113, dtype: int64

# %%
data[(data.Director == "Woody Allen" ) & (data.Genre == "Comedy") ]
# Out:
#                  Series_Title  Released_Year  Runtime   Genre  IMDB_Rating  \
# 414                Annie Hall           1977       93  Comedy          8.0
# 526   Crimes and Misdemeanors           1989      104  Comedy          7.9
# 528    Hannah and Her Sisters           1986      107  Comedy          7.9
# 533                 Manhattan           1979       96  Comedy          7.9
# 743         Midnight in Paris           2011       96  Comedy          7.7
# 835  The Purple Rose of Cairo           1985       82  Comedy          7.7
# 837                     Zelig           1983       79  Comedy          7.7
# 846            Love and Death           1975       85  Comedy          7.7
#
#         Director          Star1  No_of_Votes        Gross  Metascore
# 414  Woody Allen    Woody Allen       251823   39200000.0       92.0
# 526  Woody Allen  Martin Landau        54670   18254702.0       77.0
# 528  Woody Allen     Mia Farrow        67176   40084041.0       90.0
# ...

# %%
data[data.Director == "Alfred Hitchcock"]
# Out:
#              Series_Title  Released_Year  Runtime      Genre  IMDB_Rating  \
# 49                 Psycho           1960      109     Horror          8.5
# 81            Rear Window           1954      112    Mystery          8.4
# 118    North by Northwest           1959      136  Adventure          8.3
# 119               Vertigo           1958      128    Mystery          8.3
# 187     Dial M for Murder           1954      105      Crime          8.2
# 312               Rebecca           1940      130      Drama          8.1
# 450                  Rope           1948       80      Crime          8.0
# 556  Strangers on a Train           1951      101      Crime          7.9
# 559             Notorious           1946      102      Drama          7.9
# 712     Shadow of a Doubt           1943      108  Film-Noir          7.8
# 714     The Lady Vanishes           1938       96    Mystery          7.8
# 862             The Birds           1963      119      Drama          7.7
# ...

# %%
data.No_of_Votes.min()
# Out:
# np.int64(25088)

# %%
data[data.No_of_Votes == data.No_of_Votes.min()]
# Out:
#        Series_Title  Released_Year  Runtime  Genre  IMDB_Rating    Director  \
# 264  Ba wang bie ji           1993      171  Drama          8.1  Kaige Chen
#
#              Star1  No_of_Votes      Gross  Metascore
# 264  Leslie Cheung        25088  5216888.0        NaN

# %%
data[data.Genre == "Drama"]["IMDB_Rating"].mean()
# Out:
# np.float64(7.957439446366782)
